# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from pandas import DataFrame


#This next line makes our charts show up in the notebook
# %matplotlib inline

prescriptions_df = (pd.read_csv("Prescriptions.csv",index_col ="State"))
prescriptions_df.iloc[:0]
prescriptions_df
# Out:
#                       Year 2017  Year 2016  Year 2015  Year 2014  Year 2013  \
# State
# Alabama                   107.2      121.0      125.0      135.2      142.4
# Alaska                     52.0       58.9       60.8       62.7       63.7
# Arizona                    61.2       70.2       75.5       79.7       80.4
# Arkansas                  105.4      114.6      117.2      123.2      120.9
# California                 39.5       44.8       47.7       52.7       54.4
# Colorado                   52.9       59.8       65.1       69.6       71.2
# Connecticut                48.0       55.9       62.3       66.0       67.4
# Delaware                   68.3       79.2       84.4       91.0       92.7
# District of Columbia       28.5       32.5       35.7       40.1       41.1
# Florida                    60.9       66.6       67.1       71.4       73.5
# Georgia                    70.9       77.8       79.4       83.8       86.6
# Hawaii                     37.0       41.9       44.3       47.7       49.4
# Idaho                      70.3       77.6       81.9       87.4       89.2
# Illinois                   51.1       56.8       59.1       62.3       63.7
# Indiana                    74.2       83.9       89.1       96.7      106.3
# Iowa                       56.4       64.0       68.6       72.3       72.2
# Kansas                     69.8       76.9       80.5       86.5       88.7
# Kentucky                   86.8       97.2      102.6      110.0      111.7
# Louisiana                  89.5       98.1      100.4      108.9      112.4
# Maine                      55.7       66.9       76.5       82.4       85.9
# Maryland                   51.7       58.7       63.0       67.6       69.0
# Massachusetts              40.1       47.1       54.0       59.6       63.0
# Michigan                   74.2       84.9       90.5       98.0       98.9
# Minnesota                  41.0       46.9       52.1       56.6       58.3
# Mississippi                92.9      105.6      110.9      116.3      119.6
# Missouri                   71.8       80.4       84.5       90.7       93.3
# Montana                    61.1       69.8       73.3       80.1       84.2
# Nebraska                   56.6       62.8       65.5       70.1       71.3
# Nevada                     73.0       80.7       85.4       90.1       91.1
# New Hampshire              52.8       64.3       74.8       79.6       82.0
# New Jersey                 44.2       52.6       56.0       57.2       58.3
# New Mexico                 56.4       65.1       69.8       71.5       71.4
# New York                   37.8       42.7       45.1       43.9       46.7
# North Carolina             72.0       82.5       88.4       93.7       96.7
# North Dakota               41.5       47.8       53.0       58.1       60.1
# Ohio                       63.5       75.3       82.7       89.5       93.1
# Oklahoma                   88.1       97.9      104.4      110.9      123.3
# Oregon                     66.1       76.3       84.2       91.9       94.2
# Pennsylvania               57.7       69.5       75.5       79.9       81.6
# Rhode Island               51.2       60.3       65.7       72.8       76.9
# South Carolina             79.3       89.4       95.1      101.3      103.0
# South Dakota               49.0       54.8       59.1       61.7       60.6
# Tennessee                  94.4      107.5      114.9      121.3      127.1
# Texas                      53.1       57.6       59.8       67.0       70.0
# Utah                       63.8       70.4       74.4       78.8       82.1
# Vermont                    50.5       58.6       60.1       50.4       52.2
# Virginia                   52.9       63.4       68.1       73.5       76.6
# Washington                 57.2       64.9       69.8       74.2       75.2
# West Virginia              81.3       96.0      111.3      126.4      129.0
# Wisconsin                  52.6       62.2       67.5       71.9       73.8
# Wyoming                    64.8       71.1       75.4       80.9       81.5
#
#                       Year 2012  Year 2011  Year 2010  Year 2009  Year 2008  \
# State
# Alabama                   143.8      136.6      134.3      131.6      126.1
# Alaska                     66.8       68.0       68.4       67.3       68.5
# Arizona                    85.3       88.6       88.5       84.2       80.9
# Arkansas                  121.8      115.2      120.8      116.0      112.1
# California                 56.4       55.9       55.8       55.6       55.1
# Colorado                   73.5       73.0       72.0       69.8       67.7
# Connecticut                69.3       69.1       68.6       68.1       68.7
# Delaware                   94.0       99.7      101.1       97.5       95.4
# District of Columbia       40.3       39.8       37.1       34.4       34.5
# Florida                    75.9       83.5       87.6       86.3       84.3
# Georgia                    89.4       88.6       90.2       88.2       86.3
# Hawaii                     50.4       50.1       50.1       47.8       46.6
# Idaho                      92.0       91.4       88.6       85.2       82.7
# Illinois                   66.1       64.3       63.1       61.0       60.2
# Indiana                   110.5      106.7      107.1      105.6      103.3
# Iowa                       74.1       64.0       62.3       60.4       59.1
# Kansas                     90.3       87.8       86.1       82.8       82.7
# Kentucky                  127.9      137.0      136.5      135.2      136.6
# Louisiana                 113.0      111.7      112.6      113.0      113.7
# Maine                      89.7       93.1       92.8       87.9       88.7
# Maryland                   72.2       72.9       71.2       66.9       65.5
# Massachusetts              65.7       65.9       67.9       68.9       69.2
# Michigan                  100.7       98.8       96.0       91.6       89.9
# Minnesota                  60.9       60.0       59.0       58.6       56.5
# Mississippi               121.8      117.2      118.1      117.3      113.2
# Missouri                   95.4       91.6       91.0       88.5       86.8
# Montana                    87.7       85.3       87.2       85.8       85.3
# Nebraska                   73.2       68.8       69.0       66.4       66.2
# Nevada                     98.9      100.3       97.3       94.0       97.0
# New Hampshire              83.7       80.9       81.6       81.5       81.7
# New Jersey                 60.1       61.5       61.0       59.9       59.5
# New Mexico                 76.8       81.6       81.9       75.3       71.4
# New York                   51.8       51.1       51.0       49.5       48.4
# North Carolina             98.6       93.5       93.1       89.3       88.6
# North Dakota               62.1       61.3       63.0       60.3       61.7
# Ohio                       97.5      101.5      102.4      100.4       97.5
# Oklahoma                  127.4      122.3      119.6      115.0      111.3
# Oregon                     98.7      100.7      101.2       99.3       99.1
# Pennsylvania               83.3       81.7       81.0       78.1       76.5
# Rhode Island               83.2       82.5       82.7       82.5       82.9
# South Carolina            104.0       96.8       98.6       95.8       94.1
# South Dakota               60.1       55.1       54.0       52.3       52.1
# Tennessee                 136.1      138.5      140.0      138.4      132.9
# Texas                      73.4       72.0       73.0       71.8       71.3
# Utah                       84.5       85.2       86.6       86.9       91.3
# Vermont                    54.6       53.6       54.1       54.5       56.5
# Virginia                   79.6       76.6       75.5       74.1       73.0
# Washington                 78.7       81.6       85.0       86.1       86.6
# West Virginia             136.9      139.6      143.1      146.9      145.5
# Wisconsin                  76.8       75.2       74.4       71.9       70.6
# Wyoming                    80.5       78.2       80.4       81.0       81.0
#
#                       Year 2007  Year 2006
# State
# Alabama                   120.3      115.6
# Alaska                     66.6       63.4
# Arizona                    77.8       74.3
# Arkansas                  108.2       98.3
# California                 53.6       51.0
# Colorado                   65.9       62.2
# Connecticut                67.5       64.7
# Delaware                   92.3       86.6
# District of Columbia       41.2       31.7
# Florida                    82.2       79.7
# Georgia                    82.5       79.8
# Hawaii                     44.5       42.3
# Idaho                      78.8       75.6
# Illinois                   59.2       55.6
# Indiana                    99.7       94.3
# Iowa                       57.1       59.3
# Kansas                     80.6       77.5
# Kentucky                  130.8      122.6
# Louisiana                 110.1      109.2
# Maine                      85.4       83.6
# Maryland                   63.3       60.1
# Massachusetts              68.2       66.0
# Michigan                   85.6       80.2
# Minnesota                  53.7       50.3
# Mississippi               109.9      102.7
# Missouri                   84.3       80.5
# Montana                    81.1       79.1
# Nebraska                   65.1       64.3
# Nevada                     90.2       87.7
# New Hampshire              78.5       75.0
# New Jersey                 57.2       54.7
# New Mexico                 69.0       61.8
# New York                   46.1       44.2
# North Carolina             87.5       85.2
# North Dakota               59.3       56.0
# Ohio                       92.7       87.7
# Oklahoma                  114.4      108.7
# Oregon                     95.5       91.0
# Pennsylvania               73.7       69.5
# Rhode Island               82.2       78.7
# South Carolina             91.7       90.4
# South Dakota               49.9       50.0
# Tennessee                 128.8      124.8
# Texas                      71.2       66.8
# Utah                       89.8       87.0
# Vermont                    56.0       56.9
# Virginia                   70.1       67.2
# Washington                 84.4       80.8
# West Virginia             135.1      129.9
# Wisconsin                  69.2       64.7
# Wyoming                    80.8       79.9

# %%
sum_year = pd.DataFrame(prescriptions_df.sum(axis = 0, skipna = True) )
sum_year.rename(columns = {sum_year.columns[0]: 'Total'}, inplace = True)
sum_year.sort_index(inplace=True)
sum_year
# Out:
#             Total
# Year 2006  3909.1
# Year 2007  4088.8
# Year 2008  4216.3
# Year 2009  4266.7
# Year 2010  4363.5
# Year 2011  4355.9
# Year 2012  4395.4
# Year 2013  4237.9
# Year 2014  4115.1
# Year 2015  3857.5
# Year 2016  3611.7
# Year 2017  3178.2

# %%
sum_year.plot(y='Total', kind='line', alpha=0.75, color="teal", linewidth=6, linestyle='dashed', stacked=False, figsize=(20, 10))
plt.ylabel('# Opioids Prescribed per Capita', fontsize=14, fontweight=0)
plt.title('Prescription Drugs', loc='left', fontsize=18, fontweight=0, color='blue')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-43fac9a89015> in <module>
#       9
#      10 # multiple line plot
# ---> 11 for column in df.drop('x', axis=1):
#      12    plt.plot(df['x'], df[column], marker='', color='grey', linewidth=1, alpha=0.4)
#      13
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['x'] not found in axis"

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Death_Rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-4c5a7d377b32> in <module>
#       1 Mean_Data = pd.DataFrame(prescriptions_df.groupby(['State']).mean())
# ----> 2 Mean_Most = Mean_Data.nlargest(10,'Death_Rate')
#       3
#       4 Mean_Most.plot(kind="bar", y= "State", color = 'teal', use_index=True)
#       5 plt.title('Top Ten States by Highest Death Rate')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in nlargest(self, n, columns, keep)
#    5194         Brunei      434000    12128      BN
#    5195         """
# -> 5196         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5197
#    5198     def nsmallest(self, n, columns, keep="first"):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in nlargest(self)
#    1121
#    1122     def nlargest(self):
# -> 1123         return self.compute("nlargest")
#    1124
#    1125     def nsmallest(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in compute(self, method)
#    1239
#    1240         for column in columns:
# -> 1241             dtype = frame[column].dtype
#    1242             if not self.is_valid_dtype_n_method(dtype):
#    1243                 raise TypeError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Death_Rate'
